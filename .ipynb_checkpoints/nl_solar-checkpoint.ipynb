# %% [markdown]
# # Running the Netherlands on solar energy
# How much land would it take to run the Netherlands on solar energy?
#
# In order to answer this question, we need to know how much energy the Netherlands consumes per year, and how much energy can be produced in the Netherlands per square kilometer. We will keep energy production pretty simple - according to the CBS (central bureau of statistics) of the Netherlands, [the total energy consumption in the country amounted to 3157 PJ in 2017](https://longreads.cbs.nl/trends18-eng/economy/figures/energy/). **That's about 877 billion kwh per year.** For the sake of simplicity, we will just use this number.
#
# Energy production will be more complex. We need to know how much sunlight the Netherlands receives per year, and how much of this sunlight can be converted into energy using solar panels. With this information, we can estimate how much land will be required to power the country using solar panels.
#
# useful links:
# * our world in data on renewable energy: https://ourworldindata.org/renewable-energy

# %%
import rasterio as rs
import numpy as np
from rasterio.plot import show
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## How much sunlight does the Netherlands receive per year?
# * Solar irradiance: https://en.wikipedia.org/wiki/Solar_irradiance
# * Solar resource maps: https://solargis.com/maps-and-gis-data/download/netherlands
# * Global solar atlas: https://globalsolaratlas.info/download/netherlands
#
# GTI = Longterm yearly average of global irradiation at optimum tilt (GTI) in kWh/m2, covering the period 1994-2018

# %%
pc2 = gpd.read_file('data/nl_pc2_amersfoort.shp')
pc4 = gpd.read_file('data/nl_pc4_amersfoort.shp')

# %%
gdf = gpd.read_file('data/nl_solarAtlas/solarPotential_cropped.shp')
gdf = gdf.sort_values(by='kwhPerYear', ascending=False).reset_index(drop=True)
gdf.head()
# Out:
#            gti    kwhPerYear  pc  \
# 0  1343.806030  9.739325e+08  43
# 1  1341.575317  9.723158e+08  43
# 2  1340.241089  9.713488e+08  43
# 3  1338.161255  9.698414e+08  43
# 4  1338.121948  9.698129e+08  43
#
#                                             geometry
# 0  POLYGON ((25607.884 394603.814, 27807.079 3946...
# 1  POLYGON ((27807.079 394603.814, 30006.273 3946...
# 2  POLYGON ((23408.690 394603.814, 25607.884 3946...
# 3  POLYGON ((25607.884 396800.851, 27807.079 3968...
# 4  POLYGON ((27807.079 396800.851, 30006.273 3968...

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
gdf.plot(column='kwhPerYear', legend=True, ax=ax)
ax.axis('off')
ax.set_title('Potential energy produced per year with solar (kwh)')
plt.show()

# %%
totalEnergyConsumptionNl = 876944444444
kwhTot = 0
for i, row in gdf.iterrows(): 
    kwh = row.kwhPerYear
    kwhTot += kwh
    if kwhTot >= totalEnergyConsumptionNl: 
        break

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
gdf.plot(color='lightgrey', ax=ax)
gdf[:i].plot(ax=ax, color='red')
ax.axis('off')
ax.set_title('Land required to power entire country with solar')
plt.show()

# %%
# %%time
# read file 
landuse = gpd.read_file('data/landuse_amersfoort.shp')

# simplify geometry 
def simpGeom(x): 
    thresh = math.sqrt(x.area) / 10
    x_simp = x.simplify(thresh, preserve_topology=False)
    return x_simp
landuse['geomSimp'] = landuse.geometry.map(lambda x: simpGeom(x))

# define bounds for nl
maxx_nl = pc2.bounds.max().maxx
maxy_nl = pc2.bounds.max().maxy
minx_nl = pc2.bounds.min().minx
miny_nl = pc2.bounds.min().miny

def outOfBounds(x, maxx_nl, maxy_nl, minx_nl, miny_nl):     
    minx, miny, maxx, maxy = x.bounds
    if maxx > maxx_nl or maxy > maxy_nl or minx < minx_nl or miny < miny_nl: 
        inNl = False 
    else: 
        inNl = True
    return inNl

landuse['inNl'] = landuse.geometry.map(lambda x: outOfBounds(x, maxx_nl, maxy_nl, minx_nl, miny_nl))
landuse = landuse[landuse.inNl == True]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Miniconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# ~\Miniconda3\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     580                 feature = feature.__geo_interface__
#     581             row = {
# --> 582                 "geometry": shape(feature["geometry"]) if feature["geometry"] else None
#     583             }
#     584             # load properties
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\geo.py in shape(context)
#     103         return LineString(ob["coordinates"])
#     104     elif geom_type == "polygon":
# --> 105         return Polygon(ob["coordinates"][0], ob["coordinates"][1:])
#     106     elif geom_type == "multipoint":
#     107         return MultiPoint(ob["coordinates"])
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\polygon.py in __init__(self, shell, holes)
#     241
#     242         if shell is not None:
# --> 243             ret = geos_polygon_from_py(shell, holes)
#     244             if ret is not None:
#     245                 self._geom, self._ndim = ret
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\polygon.py in geos_polygon_from_py(shell, holes)
#     537
#     538         return (
# --> 539             lgeos.GEOSGeom_createPolygon(
#     540                 c_void_p(geos_shell), geos_holes, L), ndim)
#
# KeyboardInterrupt:

# %%
landuse.drop(columns=['geometry'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6857151207cc> in <module>
# ----> 1 landuse.drop(columns=['geometry'])
#
# NameError: name 'landuse' is not defined

# %%
landuse.drop(columns=['geometry'])
landuse.rename(columns={'geomSimp': 'geometry'}, inplace=True)
landuse.head()

# %%
landuse.to_file('data/landuse_amersfort_shp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-2412269a3b8d> in <module>
# ----> 1 landuse.to_file('data/landuse_amersfort_shp')
#
# ~\Miniconda3\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1084         from geopandas.io.file import _to_file
#    1085
# -> 1086         _to_file(self, filename, driver, schema, index, **kwargs)
#    1087
#    1088     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# ~\Miniconda3\lib\site-packages\geopandas\io\file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     302         df = df.reset_index(drop=False)
#     303     if schema is None:
# --> 304         schema = infer_schema(df)
#     305     if crs:
#     306         crs = pyproj.CRS.from_user_input(crs)
#
# ~\Miniconda3\lib\site-packages\geopandas\io\file.py in infer_schema(df)
#     352
#     353     properties = OrderedDict(
# --> 354         [
#     355             (col, convert_type(col, _type))
#     356             for col, _type in zip(df.columns, df.dtypes)
#
# ~\Miniconda3\lib\site-packages\geopandas\io\file.py in <listcomp>(.0)
#     353     properties = OrderedDict(
#     354         [
# --> 355             (col, convert_type(col, _type))
#     356             for col, _type in zip(df.columns, df.dtypes)
#     357             if col != df._geometry_column_name
#
# ~\Miniconda3\lib\site-packages\geopandas\io\file.py in convert_type(column, in_type)
#     346             out_type = types[str(in_type)]
#     347         else:
# --> 348             out_type = type(np.zeros(1, in_type).item()).__name__
#     349         if out_type == "long":
#     350             out_type = "int"
#
# TypeError: Cannot interpret '<geopandas.array.GeometryDtype object at 0x000001F7DA950FD0>' as a data type

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10))
landuse.plot(ax=ax)
pc2.plot(ax=ax, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-83811f604f49> in <module>
#       1 fig, ax = plt.subplots(1,1,figsize=(10,10))
# ----> 2 landuse.plot(ax=ax)
#       3 pc2.plot(ax=ax, color='red')
#       4 plt.show()
#
# ~\Miniconda3\lib\site-packages\geopandas\plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ~\Miniconda3\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     687
#     688     if column is None:
# --> 689         return plot_series(
#     690             df.geometry,
#     691             cmap=cmap,
#
# ~\Miniconda3\lib\site-packages\geopandas\plotting.py in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     426     expl_series = geopandas.GeoSeries(geoms)
#     427
# --> 428     geom_types = expl_series.type
#     429     poly_idx = np.asarray((geom_types == "Polygon") | (geom_types == "MultiPolygon"))
#     430     line_idx = np.asarray(
#
# ~\Miniconda3\lib\site-packages\geopandas\base.py in type(self)
#     197     def type(self):
#     198         """Return the geometry type of each geometry in the GeoSeries"""
# --> 199         return self.geom_type
#     200
#     201     @property
#
# ~\Miniconda3\lib\site-packages\geopandas\base.py in geom_type(self)
#     192         dtype: object
#     193         """
# --> 194         return _delegate_property("geom_type", self)
#     195
#     196     @property
#
# ~\Miniconda3\lib\site-packages\geopandas\base.py in _delegate_property(op, this)
#      65     # type: (str, GeoSeries) -> GeoSeries/Series
#      66     a_this = GeometryArray(this.geometry.values)
# ---> 67     data = getattr(a_this, op)
#      68     if isinstance(data, GeometryArray):
#      69         from .geoseries import GeoSeries
#
# ~\Miniconda3\lib\site-packages\geopandas\array.py in geom_type(self)
#     479     @property
#     480     def geom_type(self):
# --> 481         return vectorized.geom_type(self.data)
#     482
#     483     @property
#
# ~\Miniconda3\lib\site-packages\geopandas\_vectorized.py in geom_type(data)
#     524         return geometry_type_values[np.searchsorted(geometry_type_ids, res)]
#     525     else:
# --> 526         return _unary_op("geom_type", data, null_value=None)
#     527
#     528
#
# ~\Miniconda3\lib\site-packages\geopandas\_vectorized.py in _unary_op(op, left, null_value)
#     455     # type: (str, np.array[geoms], Any) -> np.array
#     456     """Unary operation that returns a Series"""
# --> 457     data = [getattr(geom, op, null_value) for geom in left]
#     458     return np.array(data, dtype=np.dtype(type(null_value)))
#     459
#
# ~\Miniconda3\lib\site-packages\geopandas\_vectorized.py in <listcomp>(.0)
#     455     # type: (str, np.array[geoms], Any) -> np.array
#     456     """Unary operation that returns a Series"""
# --> 457     data = [getattr(geom, op, null_value) for geom in left]
#     458     return np.array(data, dtype=np.dtype(type(null_value)))
#     459
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\base.py in geom_type(self)
#     430     def geom_type(self):
#     431         """Name of the geometry's type, such as 'Point'"""
# --> 432         return self.geometryType()
#     433
#     434     # Real-valued properties and methods
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\base.py in geometryType(self)
#     354
#     355     def geometryType(self):
# --> 356         return geometry_type_name(self._geom)
#     357
#     358     @property
#
# ~\Miniconda3\lib\site-packages\shapely\geometry\base.py in geometry_type_name(g)
#      70     if g is None:
#      71         raise ValueError("Null geometry has no type")
# ---> 72     return GEOMETRY_TYPES[lgeos.GEOSGeomTypeId(g)]
#      73
#      74
#
# KeyboardInterrupt:

# %%
landForSolar_min_list = ['grass', 'heath', 'scrub', 'meadow']
landForSolar_max_list = ['allotments', 'grass', 'cemetery', 'industrial', 'heath',
                    'military', 'farmland', 'scrub', 'meadow', 'farmyard', 'vineyard', 'orchard']

landForSolar_min = landuse[landuse.fclass.isin(landForSolar_min_list)]
landForSolar_max = landuse[landuse.fclass.isin(landForSolar_max_list)]

# %%
728 * 50 / 1000
# Out:
# 36.4

# %%
x = landuse.loc[0, 'geometry']
minx, miny, maxx, maxy = x.bounds
maxx
# Out:
# 136872.6953275525

# %%
maxy
# Out:
# 615045.3397637472

# %%
landForSolar_max.bounds.max().maxy
# Out:
# 841336.9011058754

# %%
landuse.head()
# Out:
#     osm_id  code          fclass                        name  \
# 0  3217163  7202            park             Abraham Dolehof
# 1  3243982  7202            park                        None
# 2  4002474  7202            park                   Molenpark
# 3  4100649  7210  nature_reserve                        None
# 4  4233384  7202            park  Jochem Uytdehaageplantsoen
#
#                                             geometry  \
# 0  POLYGON ((136832.837 455579.918, 136861.480 45...
# 1  POLYGON ((136687.733 455485.667, 136706.934 45...
# 2  POLYGON ((135211.862 455716.128, 135269.040 45...
# 3  POLYGON ((370540.416 679258.050, 370533.764 67...
# 4  POLYGON ((134428.142 455134.332, 134443.588 45...
#
#                                             geomSimp
# 0  POLYGON ((136832.837 455579.918, 136861.480 45...
# 1  POLYGON ((136687.733 455485.667, 136706.934 45...
# 2  POLYGON ((135211.862 455716.128, 135265.960 45...
# 3  POLYGON ((370540.416 679258.050, 370798.903 68...
# 4  POLYGON ((134428.142 455134.332, 134492.957 45...

# %%
# %%time
landForSolar_max.geometry.plot()
# Out:
# Wall time: 3min 3s

# %%
# %%time
landForSolar_max.geomSimp.plot()
# Out:
# Wall time: 3min 15s
